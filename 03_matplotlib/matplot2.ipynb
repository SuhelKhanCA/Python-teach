# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([2, 9, 15, -5])
y = np.array([5, 6, 10, 20])

# %%
plt.plot(x, y)
plt.show()

# %%
x = np.array([0, 0.5, 2, 2.5, 3])
y = np.array([0, 0.25, 4, 6.25, 9])

# %%
plt.plot(x, y, '*--k', ms=23)
plt.show()
