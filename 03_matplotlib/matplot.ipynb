# %%
pip install matplotlib

# %%
import matplotlib as mt

# %%
mt.__version__
# Out:
# '3.10.0'

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.array([0, 1])
y = np.array([3, 5])

# %%
plt.plot(x, y)

# %%
plt.show()

# %%
# BONUS

lab = ['Python', 'Java', 'JS', 'Cpp']
pop = [90.5, 70, 90, 10]
plt.pie(pop, labels=lab, autopct='%1.2f%%')
plt.show()
