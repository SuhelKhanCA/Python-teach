# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x1 = np.array([1, 2, 5, 2, 9, 23])
x2 = np.array([0, 11, 15, 20, 12, 4])

# %%
y1 = np.array([11, 22, 55, 52, 9, 23])
y2 = np.array([10, 1, 5, 2, 22, 14])

# %%
plt.plot(x1, y1)
plt.plot(x2, y2)

# %%
plt.plot(x1, y1, x2, y2)
